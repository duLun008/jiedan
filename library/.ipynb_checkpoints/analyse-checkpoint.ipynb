# %%
import pandas as pd

jiehuan = {}
reader = pd.read_excel('data/读者信息.xlsx')
content = pd.read_excel('data/图书目录.xlsx')
for year in ['2014', '2015', '2016', '2017']:
    filename = 'data/图书借还{}.xlsx'.format(year)
    jiehuan[year] = pd.read_excel(filename)

# %%
print(len(set(content['图书分类号'])))
print(len(content))
# Out:
# 339651
# 400966

# %%
def get_class():
    bc = {}
    with open("data/《中国图书馆图书分类法》简表.txt", 'r', encoding='utf8') as rf:
        for line in rf:
            if line[0] >='A' and line[0] <='Z':
                res = line.split()
                if len(res)> 1:
                    bc[res[0]]=res[1]
                else:
                    for i in range(len(line)-1, -1, -1):
                        if line[i]>='0' and line[i]<='9':
                            bc[line[:i+1]] = line[i+1:]
                            break
    return bc
book_class = get_class()

def parse_classification_number(classification_number):

    parts = classification_number.split('.') if '.' in classification_number else classification_number.split('/')
    

    main_class_number = parts[0].strip()
    secondary_class_number = parts[1].strip() if len(parts) > 1 else ""
    main_class = None
    secondary_class = None
    if main_class_number in book_class:
        main_class = book_class[main_class_number]
    if secondary_class_number in book_class:
        secondary_class = book_class[secondary_class_number]
    return main_class, secondary_class

# %%
for year in jiehuan:
    borrow_df = jiehuan[year]

    merge_df = pd.merge(borrow_df, content, on='图书ID')
    merge_df = pd.merge(merge_df, reader, on='读者ID')

    teacher_df = merge_df[merge_df['读者类型'] == '教师']

    category_counts = teacher_df['图书分类号'].value_counts().head(10)

    print("\n教师{}年借阅的书籍类别占前10的类别为：".format(year))
    for cls, num in category_counts.items():
        print(parse_classification_number(cls), cls, num, content[content['图书分类号']==cls]['书名'],sep='\t')
#     print(category_counts)
# Out:
# 教师2014年借阅的书籍类别占前10的类别为：
# ('当代作品（1949--', None)	I247.5/3244	12	230404    武林外史.上
# 230405    武林外史.中
# 230406    武林外史.下
# Name: 书名, dtype: object
# (None, None)	K236.042/8	10	188980    三國志.上
# 188981    三國志.下
# Name: 书名, dtype: object
# (None, None)	P618.130.2/91	10	85239     石油地质学
# 125314    石油地质学
# Name: 书名, dtype: object
# ('当代作品（1949--', None)	I247.57/2175	8	214036    皇妃出阁.下册
# 214037    皇妃出阁.上册
# 254913    皇妃出阁.上册
# 254939    皇妃出阁.下册
# Name: 书名, dtype: object
# ('中国民族器乐', None)	J632.326/3	8	177544    古筝必学教程.上册
# 177545    古筝必学教程.下册
# Name: 书名, dtype: object
# (None, None)	J212.27/60	8	147681    翅色斑斓:中国画五十一种鸟的画法.上
# 147682    翅色斑斓:中国画五十一种鸟的画法.下
# Name: 书名, dtype: object
# ('民族器乐曲', None)	J648.11/1	8	106304    笛子教学曲精选
# 106305    笛子教学曲精选
# Name: 书名, dtype: object
# ('当代作品（1949--', None)	I247.57/2403	8	225176    金牌王妃.下
# 225253    金牌王妃.上
# Name: 书名, dtype: object
# (None, None)	O346.1/24	7	83185     断裂力学及断裂物理
# 121737    断裂力学及断裂物理
# Name: 书名, dtype: object
# (None, None)	J212.27/68	7	148155    千姿百态画牡丹
# 163985    千姿百态画牡丹
# Name: 书名, dtype: object
#
# 教师2015年借阅的书籍类别占前10的类别为：
# ('个性心理、人格心理学', None)	B848/66	32	226498    潜意识与人格
# Name: 书名, dtype: object
# ('民族器乐曲', None)	J648.32/1	10	243056    中国传统古筝曲大全.下,浙江、陕西古筝流派 弦索十三套古筝谱
# 243207             中国传统古筝曲大全.上,河南、山东古筝流派
# Name: 书名, dtype: object
# ('当代作品（1949--', None)	I247.5/2035	10	157014    侠客行.上
# 157015    侠客行.下
# Name: 书名, dtype: object
# ('中国民族器乐', None)	J632.21/7	9	260269    手把手教你拉二胡:零起点最易上手的DVD二胡视频教程
# Name: 书名, dtype: object
# (None, None)	TE312/10	9	83946        现代油藏渗流力学原理
# 94867        现代油藏渗流力学原理
# 126033       现代油藏渗流力学原理
# 181975    现代油藏渗流力学原理.下册
# 182810    现代油藏渗流力学原理.下册
# 182828    现代油藏渗流力学原理.上册
# 335668    现代油藏渗流力学原理.上册
# 335669    现代油藏渗流力学原理.下册
# Name: 书名, dtype: object
# (None, None)	TE311/17	8	24374     油层物理
# 101786    油层物理
# 101801    油层物理
# 107204    油层物理
# 114597    油层物理
# 125521    油层物理
# 182976    油层物理
# 353944    油层物理
# 368073    油层物理
# 385742    油层物理
# Name: 书名, dtype: object
# (None, None)	TM911/4	8	121215    先进电池材料
# Name: 书名, dtype: object
# ('民族器乐曲', None)	J648.11/1	8	106304    笛子教学曲精选
# 106305    笛子教学曲精选
# Name: 书名, dtype: object
# ('石油、天然气', None)	TE/12	8	124771    石油工程
# Name: 书名, dtype: object
# ('当代作品（1949--', None)	I247.52/121	8	189726    朝鲜战争:修订版.上
# 189783    朝鲜战争:修订版.下
# Name: 书名, dtype: object
#
# 教师2016年借阅的书籍类别占前10的类别为：
# ('文学史、文学思想史', None)	I209/7	15	122982    中国文学史
# 122983    中国文学史
# 122984    中国文学史
# Name: 书名, dtype: object
# (None, None)	TE327/1	12	125432    陆相油田开发中后期油藏精细描述
# 181943    陆相油田开发中后期油藏精细描述
# 182861    陆相油田开发中后期油藏精细描述
# Name: 书名, dtype: object
# ('当代作品（1949--', None)	I247.48/100	12	134926    射雕英雄传
# 136638    射雕英雄传
# Name: 书名, dtype: object
# ('文学评论和研究', None)	I206.09/1	10	1281       当代文艺思潮小史
# 122115    中国文学批评史新编
# 122116    中国文学批评史新编
# Name: 书名, dtype: object
# ('当代作品（1949--', None)	I247.57/4537	8	355475    你和我的倾城时光.上
# 355476    你和我的倾城时光.下
# Name: 书名, dtype: object
# ('中国民族器乐', None)	J632.326/3	8	177544    古筝必学教程.上册
# 177545    古筝必学教程.下册
# Name: 书名, dtype: object
# ('当代作品（1949--', None)	I247.48/98	8	134924      书剑恩仇录
# 136637      书剑恩仇录
# 157035    书剑恩仇录.上
# 157036    书剑恩仇录.下
# Name: 书名, dtype: object
# (None, None)	TM911/4	8	121215    先进电池材料
# Name: 书名, dtype: object
# (None, None)	I242.4/6-3	8	87870    西游记
# 87871    西游记
# Name: 书名, dtype: object
# (None, None)	H310.421/101	8	327187    考博英语全国重点院校真题详解
# Name: 书名, dtype: object
#
# 教师2017年借阅的书籍类别占前10的类别为：
# ('各体文学评论和研究', None)	I207.419/66	11	331325    刘心武评点《金瓶梅》.上
# 331326    刘心武评点《金瓶梅》.中
# 331327    刘心武评点《金瓶梅》.下
# Name: 书名, dtype: object
# ('社会生活和社会问题', None)	C913.2-64/1	10	234405    善谋者成:图解最有效的职业规划
# Name: 书名, dtype: object
# ('中国书法、篆刻', None)	J292.113.5/1	8	99530    经典行书教案
# 99531    经典行书教案
# Name: 书名, dtype: object
# (None, None)	B83-095/4	8	189326    西方美学史.上卷
# 189327    西方美学史.下卷
# 203516     西方美学史.上
# 203517     西方美学史.下
# Name: 书名, dtype: object
# ('古代作品', None)	I222.742/68	8	202440    唐诗宋词.上
# 202441    唐诗宋词.下
# Name: 书名, dtype: object
# ('个性心理、人格心理学', None)	B848.2/21	8	379840    刻意练习:如何从新手到大师
# 386260    刻意练习:如何从新手到大师
# 387509    刻意练习:如何从新手到大师
# Name: 书名, dtype: object
# ('中国民族器乐', None)	J632.326/3	8	177544    古筝必学教程.上册
# 177545    古筝必学教程.下册
# Name: 书名, dtype: object
# (None, None)	I512.09/4	8	258641    俄国文学史:上
# 258701    俄国文学史:下
# Name: 书名, dtype: object
# ('素描、速写技法', None)	J214/206	7	272804    创意简笔画
# Name: 书名, dtype: object
# (None, None)	J624.16/14	7	233659    钢琴上的美妙旋律100首:中级简易版
# Name: 书名, dtype: object

# %%
for year in jiehuan:
    borrow_df = jiehuan[year]
    merge_df = pd.merge(borrow_df, content, on='图书ID')
    merge_df = pd.merge(merge_df, reader, on='读者ID')

    teacher_df = merge_df[(merge_df['读者类型'] == '教师')]# & ('I207.4' in merge_df['图书分类号'])]

    category_counts = teacher_df['书名'].value_counts().head(1)

    print("教师{}年最喜欢看的小说为：".format(year))
    print(category_counts)
# Out:
# 教师2014年最喜欢看的小说为：
# 测量学    16
# Name: 书名, dtype: int64
# 教师2015年最喜欢看的小说为：
# 潜意识与人格    32
# Name: 书名, dtype: int64
# 教师2016年最喜欢看的小说为：
# 西游记    20
# Name: 书名, dtype: int64
# 教师2017年最喜欢看的小说为：
# 西游记    11
# Name: 书名, dtype: int64

# %%
xiaoshuo = []
for key in book_class:
    if "小说" in book_class[key]:
        xiaoshuo.append(key)
print(xiaoshuo)
# Out:
# ['I207.4', 'I210.6', 'I246.1', 'I246.4', 'I246.5', 'I246.7', 'I247.4', 'I247.5', 'I247.51', 'I247.52', 'I247.53', 'I247.54', 'I247.55', 'I247.56', 'I247.57', 'I247.58', 'I247.59', 'I247.7', 'I247.8', 'I287.4', 'I287.45', 'I287.47']

# %%
for year in jiehuan:
    borrow_df = jiehuan[year]

    merge_df = pd.merge(borrow_df, content, on='图书ID')
    merge_df = pd.merge(merge_df, reader, on='读者ID')

    teacher_df = merge_df[(merge_df['读者类型'] == '教师') & merge_df['图书分类号'].str.contains('|'.join(xiaoshuo), case=False)]

    category_counts = teacher_df['书名'].value_counts().head(1)

    print("教师{}年最喜欢看的小说为：".format(year))
    print(category_counts)
# Out:
# 教师2014年最喜欢看的小说为：
# 雍正皇帝    8
# Name: 书名, dtype: int64
# 教师2015年最喜欢看的小说为：
# 弹痕.第二部,诡刺    6
# Name: 书名, dtype: int64
# 教师2016年最喜欢看的小说为：
# 射雕英雄传    12
# Name: 书名, dtype: int64
# 教师2017年最喜欢看的小说为：
# 平凡的世界.第三部    8
# Name: 书名, dtype: int64

# %%
book_sum = 0
all_teacher_df = pd.DataFrame()
for year in jiehuan:
    borrow_df = jiehuan[year]

    merge_df = pd.merge(borrow_df, content, on='图书ID')
    merge_df = pd.merge(merge_df, reader, on='读者ID')

    teacher_df = merge_df[(merge_df['读者类型'] == '教师')]
    all_teacher_df = pd.concat([all_teacher_df, teacher_df], ignore_index=True)
print("教师一共借阅：{}本书".format(len(all_teacher_df['操作类型']=='借')))
# Out:
# 教师一共借阅：25097本书

# %%
zhuanye_df = zhuanye_df[zhuanye_df['图书分类号'].str.startswith(('A', 'TB', 'S', 'R', 'C', 'F', 'G', 'K', 'I', 'N'))]
print("教师借阅专业书{}本".format(len(zhuanye_df)))
# Out:
# 教师借阅专业书5974本

# %%
all_teacher_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25097 entries, 0 to 25096
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   操作时间    25097 non-null  datetime64[ns]
#  1   操作类型    25097 non-null  object
#  2   图书ID    25097 non-null  object
#  3   读者ID    25097 non-null  object
#  4   书名      25097 non-null  object
#  5   图书分类号   25097 non-null  object
#  6   读者类型    25097 non-null  object
#  7   性别      25097 non-null  object
#  8   单位      25038 non-null  object
#  9           25097 non-null  object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 1.9+ MB

# %%
borrowed_books = all_teacher_df[all_teacher_df['操作类型'] == '借']


returned_books = all_teacher_df[all_teacher_df['操作类型'] == '还']

books_not_returned = borrowed_books['图书ID'].value_counts() - returned_books['图书ID'].value_counts()

num_books_not_returned = len(books_not_returned[books_not_returned > 0])

print("没有归还的书籍数量：", num_books_not_returned)
# Out:
# 没有归还的书籍数量： 420

# %%
not_returned_categories = borrowed_books[borrowed_books['图书ID'].isin(books_not_returned[books_not_returned > 0].index)]['图书分类号']


category_counts = not_returned_categories.value_counts()

most_common_category = category_counts.idxmax()

print("没有归还的书籍中数量最多的图书分类号：", most_common_category,"类别：", parse_classification_number(most_common_category))
# Out:
# 没有归还的书籍中数量最多的图书分类号： I209/7 类别： ('文学史、文学思想史', None)

# %%
set(reader['读者类型'])
# Out:
# {nan, '博士研究生', '图书馆', '教师', '教授', '本科生', '特1', '研究生', '语言短期班'}

# %%
for year in jiehuan:
    borrow_df = jiehuan[year]

    merge_df = pd.merge(borrow_df, content, on='图书ID')
    merge_df = pd.merge(merge_df, reader, on='读者ID')
    student_condition = ((merge_df['读者类型'] == '博士研究生') | (merge_df['读者类型'] == '本科生') | (merge_df['读者类型'] == '研究生'))

    student_df = merge_df[student_condition]

    category_counts = student_df['图书分类号'].value_counts().head(10)

    print("\n学生{}年借阅的书籍类别占前10的类别为：".format(year))

    for idx, category in enumerate(category_counts.items()):
        print("第{}\t图书分类号:{}\t计数值:{}\t类别:{} ".format(idx+1, category[0], category[1], parse_classification_number(category[0])))
# Out:
# 学生2014年借阅的书籍类别占前10的类别为：
# 第1	图书分类号:O13-44/210	计数值:42	类别:(None, None)
# 第2	图书分类号:I247.5/3249	计数值:39	类别:('当代作品（1949--', None)
# 第3	图书分类号:O13/291	计数值:37	类别:('高等数学', None)
# 第4	图书分类号:TU/17	计数值:36	类别:('建筑科学', None)
# 第5	图书分类号:I247.57/2834	计数值:36	类别:('当代作品（1949--', None)
# 第6	图书分类号:O13/247	计数值:36	类别:('高等数学', None)
# 第7	图书分类号:A122/2	计数值:36	类别:(None, None)
# 第8	图书分类号:I267/468	计数值:35	类别:(None, None)
# 第9	图书分类号:I247.5/2662-2	计数值:35	类别:('当代作品（1949--', None)
# 第10	图书分类号:O13/138	计数值:34	类别:('高等数学', None)
#
# 学生2015年借阅的书籍类别占前10的类别为：
# 第1	图书分类号:I712.45/609:2	计数值:60	类别:('美国文学', None)
# 第2	图书分类号:O17/130	计数值:58	类别:('数学分析', None)
# 第3	图书分类号:TE311/17	计数值:58	类别:(None, None)
# 第4	图书分类号:I247.57/2114	计数值:56	类别:('当代作品（1949--', None)
# 第5	图书分类号:G254.9/9-2	计数值:56	类别:(None, None)
# 第6	图书分类号:O241/77	计数值:56	类别:(None, None)
# 第7	图书分类号:O17/161	计数值:55	类别:('数学分析', None)
# 第8	图书分类号:O241/79	计数值:54	类别:(None, None)
# 第9	图书分类号:I247.57/722:1	计数值:54	类别:('当代作品（1949--', None)
# 第10	图书分类号:O17-44/18	计数值:51	类别:(None, None)
#
# 学生2016年借阅的书籍类别占前10的类别为：
# 第1	图书分类号:I247.7/1101	计数值:217	类别:('当代作品（1949--', None)
# 第2	图书分类号:I313.45/514	计数值:186	类别:('日本文学', None)
# 第3	图书分类号:TE311/17	计数值:168	类别:(None, None)
# 第4	图书分类号:G254.9/9-2	计数值:151	类别:(None, None)
# 第5	图书分类号:I565.45/187	计数值:148	类别:('法国文学', None)
# 第6	图书分类号:I247.81/127	计数值:139	类别:('当代作品（1949--', None)
# 第7	图书分类号:I247.57/775:2-2	计数值:136	类别:('当代作品（1949--', None)
# 第8	图书分类号:I247.57/775:1-2	计数值:133	类别:('当代作品（1949--', None)
# 第9	图书分类号:I247.55/73	计数值:127	类别:('当代作品（1949--', None)
# 第10	图书分类号:I247.59/129:3	计数值:122	类别:('当代作品（1949--', None)
#
# 学生2017年借阅的书籍类别占前10的类别为：
# 第1	图书分类号:I313.45/514	计数值:246	类别:('日本文学', None)
# 第2	图书分类号:I565.45/187	计数值:209	类别:('法国文学', None)
# 第3	图书分类号:I313.45/562-2	计数值:169	类别:('日本文学', None)
# 第4	图书分类号:I247.7/1101	计数值:165	类别:('当代作品（1949--', None)
# 第5	图书分类号:I712.45/1015	计数值:164	类别:('美国文学', None)
# 第6	图书分类号:I247.55/73	计数值:153	类别:('当代作品（1949--', None)
# 第7	图书分类号:I247.59/129:3	计数值:152	类别:('当代作品（1949--', None)
# 第8	图书分类号:I247.7/1211	计数值:147	类别:('当代作品（1949--', None)
# 第9	图书分类号:I247.57/775:1-2	计数值:147	类别:('当代作品（1949--', None)
# 第10	图书分类号:G254.9/9-2	计数值:147	类别:(None, None)

# %%
for year in jiehuan:
    borrow_df = jiehuan[year]

    merge_df = pd.merge(borrow_df, content, on='图书ID')
    merge_df = pd.merge(merge_df, reader, on='读者ID')
    student_condition = ((merge_df['读者类型'] == '博士研究生') | (merge_df['读者类型'] == '本科生') | (merge_df['读者类型'] == '研究生'))

    student_df = merge_df[student_condition & merge_df['图书分类号'].str.contains('|'.join(xiaoshuo), case=False)]# & ('I207.4' in merge_df['图书分类号'])]


    category_counts = student_df['书名'].value_counts().head(1)


    print("学生{}年最喜欢看的小说为：".format(year))
    print(category_counts)
# Out:
# 学生2014年最喜欢看的小说为：
# 平凡的世界    65
# Name: 书名, dtype: int64
# 学生2015年最喜欢看的小说为：
# 平凡的世界    191
# Name: 书名, dtype: int64
# 学生2016年最喜欢看的小说为：
# 活着    191
# Name: 书名, dtype: int64
# 学生2017年最喜欢看的小说为：
# 白鹿原    235
# Name: 书名, dtype: int64

# %%
book_sum = 0
all_student_df = pd.DataFrame()
for year in jiehuan:
    borrow_df = jiehuan[year]

    merge_df = pd.merge(borrow_df, content, on='图书ID')
    merge_df = pd.merge(merge_df, reader, on='读者ID')
    student_condition = ((merge_df['读者类型'] == '博士研究生') | (merge_df['读者类型'] == '本科生') | (merge_df['读者类型'] == '研究生'))

    student_df = merge_df[student_condition]
    all_student_df = pd.concat([all_student_df, student_df], ignore_index=True)
print("学生一共借阅：{}本书".format(len(all_student_df['操作类型']=='借')))
# Out:
# 学生一共借阅：617147本书

# %%
student_jieyue  = all_student_df[all_student_df['操作类型']=='借']
student_jieyue['图书分类号'] = student_jieyue['图书分类号'].fillna('')
student_zhuanye_df = student_jieyue[student_jieyue['图书分类号'].str.startswith(('A', 'TB', 'S', 'R', 'C', 'F', 'G', 'K', 'I', 'N'))]
print("学生借阅专业书{}本".format(len(student_zhuanye_df)))
# Out:
# 学生借阅专业书142756本
# C:\Users\dulun\AppData\Local\Temp\ipykernel_15956\2416091143.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   student_jieyue['图书分类号'] = student_jieyue['图书分类号'].fillna('')

# %%
student_borrowed_books = all_student_df[all_student_df['操作类型'] == '借']


student_returned_books = all_student_df[all_student_df['操作类型'] == '还']


student_books_not_returned = student_borrowed_books['图书ID'].value_counts() - student_returned_books['图书ID'].value_counts()


student_num_books_not_returned = len(student_books_not_returned[student_books_not_returned > 0])


print("学生没有归还的书籍数量：", student_num_books_not_returned)
# Out:
# 学生没有归还的书籍数量： 9735

# %%
studetn_not_returned_categories = student_borrowed_books[student_borrowed_books['图书ID'].isin(student_books_not_returned[student_books_not_returned > 0].index)]['图书分类号']


sutdent_category_counts = studetn_not_returned_categories.value_counts()


student_most_common_category = sutdent_category_counts.idxmax()


print("学生没有归还的书籍中数量最多的图书分类号：", student_most_common_category,"类别：", parse_classification_number(student_most_common_category))
# Out:
# 学生没有归还的书籍中数量最多的图书分类号： I313.45/514 类别： ('日本文学', None)

# %%
teacher_top_10 = all_teacher_df[(all_teacher_df['操作类型']=='借')]['图书分类号'].value_counts().head(10)
student_top_10 = all_student_df[(all_student_df['操作类型']=='借')]['图书分类号'].value_counts().head(10)
print(teacher_top_10, student_top_10)
# Out:
# B848/66          17
# J632.326/3       16
# I209/7           12
# J632.21/7        11
# J212.27/68       10
# I247.52/143:2     9
# J212.27/65        9
# R245.9/13         9
# I247.57/2342      9
# I247.5/2035       8
# Name: 图书分类号, dtype: int64 I313.45/514        236
# I247.7/1101        212
# I565.45/187        197
# G254.9/9-2         185
# I247.81/127        166
# I247.59/129:3      160
# I247.55/73         159
# TE311/17           158
# I775.45/8          155
# I247.57/775:1-2    152
# Name: 图书分类号, dtype: int64

# %%
teacher_points = {}

for year in jiehuan:
    borrow_df = jiehuan[year]
    merge_df = pd.merge(borrow_df, content, on='图书ID')
    merge_df = pd.merge(merge_df, reader, on='读者ID')
    merge_df = merge_df[(merge_df['操作类型']=='借') & (merge_df['读者类型'] == '教师')]
    
    for bid, bnum in teacher_top_10.items():
        if bid not in teacher_points:
            teacher_points[bid]=[]
        teacher_points[bid].append(len(merge_df[merge_df['图书分类号']==bid]))
print(teacher_points)
# Out:
# {'B848/66': [1, 16, 0, 0], 'J632.326/3': [4, 4, 4, 4], 'I209/7': [0, 0, 9, 3], 'J632.21/7': [1, 5, 3, 2], 'J212.27/68': [4, 2, 2, 2], 'I247.52/143:2': [3, 3, 3, 0], 'J212.27/65': [3, 2, 2, 2], 'R245.9/13': [4, 3, 2, 0], 'I247.57/2342': [3, 3, 0, 3], 'I247.5/2035': [0, 6, 2, 0]}

# %%
student_points = {}

for year in jiehuan:
    borrow_df = jiehuan[year]
    merge_df = pd.merge(borrow_df, content, on='图书ID')
    merge_df = pd.merge(merge_df, reader, on='读者ID')
    student_condition = ((merge_df['读者类型'] == '博士研究生') | (merge_df['读者类型'] == '本科生') | (merge_df['读者类型'] == '研究生'))
    merge_df = merge_df[(merge_df['操作类型']=='借') & student_condition]
    
    for bid, bnum in student_top_10.items():
        if bid not in student_points:
            student_points[bid]=[]
        student_points[bid].append(len(merge_df[merge_df['图书分类号']==bid]))
print(student_points)
# Out:
# {'I313.45/514': [0, 14, 99, 123], 'I247.7/1101': [0, 15, 115, 82], 'I565.45/187': [0, 18, 79, 100], 'G254.9/9-2': [3, 31, 75, 76], 'I247.81/127': [0, 19, 74, 73], 'I247.59/129:3': [0, 21, 61, 78], 'I247.55/73': [0, 16, 65, 78], 'TE311/17': [1, 29, 85, 43], 'I775.45/8': [4, 17, 62, 72], 'I247.57/775:1-2': [0, 7, 70, 75]}

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 6))
    
years = [2014, 2015, 2016, 2017]
years = np.array(years, dtype=int)
for key in student_points:
    plt.plot(years, student_points[key], marker='o', label=key)

plt.title(f"Top 10 Book Categories for Students (2014-2017)")
plt.xlabel("Year")
plt.ylabel("Count")
plt.xticks(years)

plt.legend(title="Book Categories")

plt.show()

# %%
plt.figure(figsize=(10, 6))
    
years = [2014, 2015, 2016, 2017]
np.array(years, dtype=int)
for key in teacher_points:
    plt.plot(years, teacher_points[key], marker='o', label=key)

plt.title(f"Top 10 Book Categories for Teachers (2014-2017)")
plt.xlabel("Year")
plt.ylabel("Count")
plt.xticks(years)

plt.legend(title="Book Categories")
plt.xticks(years)

plt.show()

# %%
xs_teacher_top_10 = all_teacher_df[(all_teacher_df['操作类型']=='借') & all_teacher_df['图书分类号'].str.contains('|'.join(xiaoshuo), case=False) ]['图书分类号'].value_counts().head(10)
xs_student_top_10 = all_student_df[(all_student_df['操作类型']=='借') & all_student_df['图书分类号'].str.contains('|'.join(xiaoshuo), case=False) ]['图书分类号'].value_counts().head(10)
print(xs_teacher_top_10, xs_student_top_10)
# Out:
# I247.57/2342     9
# I247.52/143:2    9
# I247.5/2035      8
# I207.419/66      7
# I247.48/100      6
# I247.57/2175     6
# I247.5/3244      6
# I247.57/2143     6
# I247.7/742       5
# I247.55/73:2     5
# Name: 图书分类号, dtype: int64 I247.7/1101        212
# I247.81/127        166
# I247.59/129:3      160
# I247.55/73         159
# I247.57/775:1-2    152
# I247.7/1211        147
# I247.57/775:2-2    137
# I247.5/2662-2      127
# I246.7/113         126
# I247.55/73:2       119
# Name: 图书分类号, dtype: int64

# %%
print()
parse_classification_number('I247.57/2342')
# Out:
# ('当代作品（1949--', None)

# %%
xs_teacher_points = {}

for year in jiehuan:
    borrow_df = jiehuan[year]
    merge_df = pd.merge(borrow_df, content, on='图书ID')
    merge_df = pd.merge(merge_df, reader, on='读者ID')
    merge_df = merge_df[(merge_df['操作类型']=='借') & (merge_df['读者类型'] == '教师')]
    
    for bid, bnum in xs_teacher_top_10.items():
        if bid not in xs_teacher_points:
            xs_teacher_points[bid]=[]
        xs_teacher_points[bid].append(len(merge_df[merge_df['图书分类号']==bid]))
print(xs_teacher_points)
# Out:
# {'I247.57/2342': [3, 3, 0, 3], 'I247.52/143:2': [3, 3, 3, 0], 'I247.5/2035': [0, 6, 2, 0], 'I207.419/66': [0, 0, 0, 7], 'I247.48/100': [0, 0, 6, 0], 'I247.57/2175': [4, 0, 0, 2], 'I247.5/3244': [6, 0, 0, 0], 'I247.57/2143': [2, 0, 0, 4], 'I247.7/742': [1, 1, 0, 3], 'I247.55/73:2': [0, 2, 3, 0]}

# %%
xs_student_points = {}

for year in jiehuan:
    borrow_df = jiehuan[year]
    merge_df = pd.merge(borrow_df, content, on='图书ID')
    merge_df = pd.merge(merge_df, reader, on='读者ID')
    student_condition = ((merge_df['读者类型'] == '博士研究生') | (merge_df['读者类型'] == '本科生') | (merge_df['读者类型'] == '研究生'))
    merge_df = merge_df[(merge_df['操作类型']=='借') & student_condition]
    
    for bid, bnum in xs_student_top_10.items():
        if bid not in xs_student_points:
            xs_student_points[bid]=[]
        xs_student_points[bid].append(len(merge_df[merge_df['图书分类号']==bid]))
print(xs_student_points)
# Out:
# {'I247.7/1101': [0, 15, 115, 82], 'I247.81/127': [0, 19, 74, 73], 'I247.59/129:3': [0, 21, 61, 78], 'I247.55/73': [0, 16, 65, 78], 'I247.57/775:1-2': [0, 7, 70, 75], 'I247.7/1211': [0, 11, 64, 72], 'I247.57/775:2-2': [0, 6, 73, 58], 'I247.5/2662-2': [18, 24, 51, 34], 'I246.7/113': [8, 14, 41, 63], 'I247.55/73:2': [0, 13, 49, 57]}

# %%
plt.figure(figsize=(10, 6))
    
years = [2014, 2015, 2016, 2017]
np.array(years, dtype=int)
for key in xs_student_points:
    plt.plot(years, xs_student_points[key], marker='o', label=key)

plt.title(f"Top 10 novel Book Categories for Students (2014-2017)")
plt.xlabel("Year")
plt.ylabel("Count")


plt.legend(title="novel Book Categories")
plt.xticks(years)

plt.show()

# %%
plt.figure(figsize=(10, 6))
    
years = [2014, 2015, 2016, 2017]
np.array(years, dtype=int)
for key in xs_teacher_points:
    plt.plot(years, xs_teacher_points[key], marker='o', label=key)
    
plt.title(f"Top 10 novel Book Categories for Teachers (2014-2017)")
plt.xlabel("Year")
plt.ylabel("Count")

plt.legend(title="Book novel Categories")
plt.xticks(years)

plt.show()

# %%
all_df = pd.DataFrame()
for year in jiehuan:
    borrow_df = jiehuan[year]

    merge_df = pd.merge(borrow_df, content, on='图书ID')
    merge_df = pd.merge(merge_df, reader, on='读者ID')

    all_df = pd.concat([all_df, teacher_df], ignore_index=True)

# %%
len(all_df['书名'])
# !pip install wordcloud
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting wordcloud
#   Downloading https://mirrors.aliyun.com/pypi/packages/5a/5f/f4164295d6853ec6203bc728dea4da76a7145ba70482eab9e994d26e0e13/wordcloud-1.9.2-cp310-cp310-win_amd64.whl (152 kB)
#      -------------------------------------- 152.1/152.1 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in d:\software\anaconda3\lib\site-packages (from wordcloud) (3.7.0)
# Requirement already satisfied: pillow in d:\software\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: numpy>=1.6.1 in d:\software\anaconda3\lib\site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\software\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in d:\software\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\software\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in d:\software\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in d:\software\anaconda3\lib\site-packages (from matplotlib->wordcloud) (22.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\software\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in d:\software\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: six>=1.5 in d:\software\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.2

# %%
import jieba
from wordcloud import WordCloud


stopwords_files = ['data/停用词及敏感词库/baidu_stopwords.txt', 'data/停用词及敏感词库/cn_stopwords.txt',
                   'data/停用词及敏感词库/hit_stopwords.txt', 'data/停用词及敏感词库/scu_stopwords.txt',
                   'data/停用词及敏感词库/stop-words.txt']
stopwords = set()
for file in stopwords_files:
    with open(file, 'r', encoding='utf-8') as f:
        for line in f:
            stopwords.add(line.strip())
stopwords.add('版')

words_list = []
for book_name in all_df['书名']:
    words = jieba.cut(str(book_name))
    words_filtered = [word for word in words if word not in stopwords and word.strip()!='']
    words_list.extend(words_filtered)

word_counts = {}
for word in words_list:
    if word in word_counts:
        word_counts[word] += 1
    else:
        word_counts[word] = 1

# %%
font_path = r'C:\Users\dulun\Desktop\jiedan2\NotoSerifSC-Regular.otf' 

wordcloud = WordCloud(width=800, height=400, max_words=50, background_color='white', font_path=font_path)
wordcloud.generate_from_frequencies(word_counts)


plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()


top_words = sorted(word_counts.items(), key=lambda x: x[1], reverse=True)[:10]
for word, count in top_words:
    print(f'{word}: {count}')
# Out:
# 技术: 23644
# 设计: 23520
# 英语: 23504
# 考研: 23380
# 基础: 21824
# 教程: 20768
# 入门: 19600
# 习题: 18708
# 原理: 18404
# 数学: 17672
